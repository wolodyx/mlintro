# %% [markdown]
# # Основы Python
#
# **Цель:** закрепить базовые конструкции Python: типы, структуры данных, циклы, функции, чтение файлов.
#
# **Проверка:** после каждого задания выполните ячейку с `assert` — если ошибок нет, задание выполнено.

# %%
# 1. Типы данных и структуры

# Задание 1.1. Создайте список numbers из целых чисел от 1 до 10 включительно.
# TODO: numbers = ...

# Задание 1.2. Создайте словарь squares, где ключ — число от 1 до 5,
# а значение — его квадрат.
# TODO: squares = ...

# %%
assert numbers == list(range(1, 11)), "numbers — список 1..10"
assert squares == {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}, "squares — квадраты 1..5"
print("Задание 1 выполнено")

# %%
# 2. Циклы и comprehensions

# Задание 2.1. С помощью list comprehension получите список evens
# чётных чисел из диапазона 0..20 (включительно).
# TODO: evens = ...

# Задание 2.2. С помощью цикла for посчитайте сумму квадратов всех чисел из evens
# и сохраните в sum_of_squares.
# TODO: sum_of_squares = ...

# %%
assert evens == [x for x in range(21) if x % 2 == 0], "evens — чётные 0..20"
assert sum_of_squares == sum(x ** 2 for x in evens), "sum_of_squares — сумма квадратов"
print("Задание 2 выполнено")

# %%
# 3. Функции

# Задание 3.1. Напишите функцию mean(values), возвращающую среднее арифметическое.
def mean(values):
    # TODO: реализуйте функцию
    pass

# Задание 3.2. Напишите лямбда-функцию is_adult, возвращающую True, если возраст >= 18.
# TODO: is_adult = ...

# %%
assert mean([2, 4, 6]) == 4.0, "mean должна вернуть 4.0"
assert is_adult(20) is True and is_adult(15) is False, "is_adult работает неверно"
print("Задание 3 выполнено")

# %%
# 4. Строки и словари

text = "анализ данных и машинное обучение"

# Задание 4.1. Подсчитайте частоту каждого символа строки text (без пробелов)
# и сохраните результат в словарь freq (символ -> количество).
# TODO: freq = ...

# %%
expected = {"а": 4, "н": 6, "л": 1, "и": 4, "з": 1, " ": 4, "д": 1, "ы": 1,
            "х": 1, "м": 1, "ш": 1, "о": 2, "е": 3, "б": 1, "у": 1, "ч": 1}
assert freq == expected, "freq посчитан неверно"
print("Задание 4 выполнено")

# %%
# 5. Чтение данных из файла (синтетика)

# Создадим файл с числами и прочитаем его обратно.
import pathlib, tempfile

tmp = pathlib.Path(tempfile.gettempdir()) / "numbers.txt"
tmp.write_text("10\n20\n30\n40\n", encoding="utf-8")

# Задание 5.1. Прочитайте файл tmp, преобразуйте каждую строку в int
# и сохраните список в loaded.
# TODO: loaded = ...

# %%
assert loaded == [10, 20, 30, 40], "loaded должен быть [10, 20, 30, 40]"
print("Задание 5 выполнено")
print("Все задания лабораторной работы 1 выполнены.")

# %% [markdown]
# ## Решение (для самопроверки)
#
# <details><summary>Показать эталонное решение</summary>
#
# ```python
# numbers = list(range(1, 11))
# squares = {i: i ** 2 for i in range(1, 6)}
#
# evens = [x for x in range(21) if x % 2 == 0]
# sum_of_squares = 0
# for x in evens:
#     sum_of_squares += x ** 2
#
# def mean(values):
#     return sum(values) / len(values)
#
# is_adult = lambda age: age >= 18
#
# freq = {}
# for ch in text:
#     freq[ch] = freq.get(ch, 0) + 1
#
# with open(tmp, encoding="utf-8") as f:
#     loaded = [int(line) for line in f]
# ```
# </details>
